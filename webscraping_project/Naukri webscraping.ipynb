# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.naukri.com/data-scientist-jobs'

naukri_r = requests.get(url)

#print (glassdoor_read)

#print (glassdoor_read.status_code)

naukri_soup = BeautifulSoup(naukri_r.text, 'html.parser')

naukri_soup = naukri_soup.prettify()

print (naukri_soup)
# Out:
# <!DOCTYPE HTML>
# <html class="srpPage">
#  <head>
#   <link href="https://www.naukri.com/data-scientist-jobs" rel="canonical"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <link href="https://www.naukri.com/notifymanifest.json" rel="manifest"/>
#   <title>
#    Data Scientist Jobs - Naukri.com
#   </title>
#   <meta content="Apply to 2078 Data Scientist Jobs on Naukri.com, India's No.1 Job Portal. Explore Data Scientist Openings in your desired locations Now!" name="description"/>
#   <meta content="2018 Naukri.com" name="copyright"/>
#   <meta content="EN" name="content-language"/>
#   <meta content="www.naukri.com" name="author"/>
#   <meta content="document" name="resource-type"/>
#   <meta content="GLOBAL" name="distribution"/>
#   <meta content="1 day" name="revisit-after"/>
#   <meta content="general" name="rating"/>
#   <meta content="no-cache" name="pragma"/>
# ...

# %%
#https://www.workopolis.com/jobsearch/find-jobs?&st=RELEVANCE&ak=data+scientist&l=toronto%2contario&lr=50
